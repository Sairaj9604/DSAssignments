# %%
"""Q1. What is Flask Framework? What are the advantages of Flask Framework?"""

# %%
"""Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries. 
It has no database abstraction layer, form validation, or any other components where pre-existing third-party libraries provide common functions.
Advantages -
Scalable
Lightweight
Flexible
Easy to negotiate"""

# %%
"""Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
Jupyter Notebook."""

# %% [markdown]
# ![image.png](attachment:e755c37d-0895-4c34-adc9-cfeb0041ee84.png)

# %%
"""Q3. What is App routing in Flask? Why do we use app routes?"""

# %%
"""App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs 
to help users remember the URLs and make navigation simpler. Example: In our application, the URL (“/”) is associated with the root URL."""

# %%
"""Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999"""

# %% [markdown]
# ![image.png](attachment:26e26bde-ac14-4f17-a78d-914e93d3d038.png)

# %% [markdown]
# ![image.png](attachment:2b5b3752-3702-4738-b79a-f6a24002d51c.png)

# %%
"""Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function."""

# %%
"""url_for() function. It accepts the name of the function as its first argument and any number of keyword arguments, each corresponding to a 
variable part of the URL rule."""

# %%
from flask import url_for, Flask
appFlask = Flask(__name__)
@appFlask.route('/home')
def home():
   return 'We are in Home Page!'
with appFlask.test_request_context():
    print(url_for('login'))
